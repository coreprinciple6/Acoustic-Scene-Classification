# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import torchvision
from torchvision import *
from torch.utils.data import Dataset, DataLoader

import PIL
import torchvision

# %%
batch_size = 128

import PIL
import torchvision

transforms = torchvision.transforms.Compose([
   # torchvision.transforms.Resize((224,224)),
    torchvision.transforms.ColorJitter(hue=.05, saturation=.05),
    torchvision.transforms.RandomHorizontalFlip(),
    torchvision.transforms.RandomRotation(20, resample=PIL.Image.BILINEAR),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

train_dataset = datasets.ImageFolder(root='/content/drive/MyDrive/ASC/Phase_3/Image mfcc dataset/Original_Train', transform=transforms)
test_dataset = datasets.ImageFolder(root='/content/drive/MyDrive/ASC/Phase_3/Image mfcc dataset/Original_Test', transform=transforms)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:1201: UserWarning: Argument resample is deprecated and will be removed since v0.10.0. Please, use interpolation instead
#   "Argument resample is deprecated and will be removed since v0.10.0. Please, use interpolation instead"

# %%
import torchvision.models as models
import torch.nn as nn

resnet34 = models.resnet34(pretrained=True, progress=True)

for name,child in resnet34.named_children():
  print(name)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# ...
# conv1
# bn1
# relu
# maxpool
# layer1
# layer2
# layer3
# layer4
# avgpool
# fc

# %%
for name, child in resnet34.named_children():
   if name in ['layer2','layer3', 'layer4']:
       print(name + ' is unfrozen')
       for param in child.parameters():
           param.requires_grad = True
   else:
       print(name + ' is frozen')
       for param in child.parameters():
           param.requires_grad = False

resnet34.last_linear = nn.Sequential(
nn.Dropout(0.5),
nn.Linear(resnet34.fc.in_features, out_features=2),

#nn.Linear(in_features=128, out_features=2), 
  )

resnet34 = resnet34.cuda() if device else resnet34
# Out:
# conv1 is frozen
# bn1 is frozen
# relu is frozen
# maxpool is frozen
# layer1 is frozen
# layer2 is unfrozen
# layer3 is unfrozen
# layer4 is unfrozen
# avgpool is frozen
# fc is frozen

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(resnet34.parameters(), lr=0.01, momentum=0.9)

use_cuda = torch.cuda.is_available()

def accuracy(out, labels):
    _,pred = torch.max(out, dim=1)
    return torch.sum(pred==labels).item()

# %%
n_epochs = 60
print_every = 10
valid_loss_min = np.Inf
val_loss = []
val_acc = []
train_loss = []
train_acc = []
total_step = len(train_dataloader)
for epoch in range(1, n_epochs+1):
    running_loss = 0.0
    correct = 0
    total=0
    print(f'Epoch {epoch}\n')
    for batch_idx, (data_, target_) in enumerate(train_dataloader):
        data_, target_ = data_.to(device), target_.to(device)
        optimizer.zero_grad()
        
        outputs = resnet34(data_)
        loss = criterion(outputs, target_)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _,pred = torch.max(outputs, dim=1)
        correct += torch.sum(pred==target_).item()
        total += target_.size(0)
        if (batch_idx) % 20 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch, n_epochs, batch_idx, total_step, loss.item()))
    train_acc.append(100 * correct / total)
    train_loss.append(running_loss/total_step)
    print(f'\ntrain-loss: {np.mean(train_loss):.4f}, train-acc: {(100 * correct/total):.4f}')
    batch_loss = 0
    total_t=0
    correct_t=0
    with torch.no_grad():
        resnet34.eval()
        for data_t, target_t in (test_dataloader):
            data_t, target_t = data_t.to(device), target_t.to(device)
            outputs_t = resnet34(data_t)
            loss_t = criterion(outputs_t, target_t)
            batch_loss += loss_t.item()
            _,pred_t = torch.max(outputs_t, dim=1)
            correct_t += torch.sum(pred_t==target_t).item()
            total_t += target_t.size(0)
        val_acc.append(100 * correct_t/total_t)
        val_loss.append(batch_loss/len(test_dataloader))
        network_learned = batch_loss < valid_loss_min
        print(f'validation loss: {np.mean(val_loss):.4f}, Test acc: {(100 * correct_t/total_t):.4f}\n')

        
        if network_learned:
            valid_loss_min = batch_loss
            torch.save({'epoch': epoch, 'model_state_dict': resnet34.state_dict(), 'optimizer_state_dict': optimizer.state_dict(),
            'loss': loss, }, 'Trial1.pt')
            print('Improvement-Detected, save-model')
    resnet34.train()
# Out:
# Epoch 1
#
# Epoch [1/60], Step [0/108], Loss: 9.7998
# Epoch [1/60], Step [20/108], Loss: 0.2118
# Epoch [1/60], Step [40/108], Loss: 0.1282
# Epoch [1/60], Step [60/108], Loss: 0.0026
# Epoch [1/60], Step [80/108], Loss: 0.1732
# Epoch [1/60], Step [100/108], Loss: 0.0062
#
# train-loss: 0.3961, train-acc: 95.5584
# validation loss: 10.0542, Test acc: 50.0289
#
# Improvement-Detected, save-model
# Epoch 2
#
# Epoch [2/60], Step [0/108], Loss: 0.0057
# Epoch [2/60], Step [20/108], Loss: 0.0355
# Epoch [2/60], Step [40/108], Loss: 0.0034
# Epoch [2/60], Step [60/108], Loss: 0.1007
# Epoch [2/60], Step [80/108], Loss: 0.0188
# Epoch [2/60], Step [100/108], Loss: 0.0024
#
# train-loss: 0.2166, train-acc: 99.5877
# validation loss: 9.7484, Test acc: 50.0000
#
# Improvement-Detected, save-model
# Epoch 3
#
# Epoch [3/60], Step [0/108], Loss: 0.0051
# Epoch [3/60], Step [20/108], Loss: 0.0021
# Epoch [3/60], Step [40/108], Loss: 0.0085
# Epoch [3/60], Step [60/108], Loss: 0.0033
# ...

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(20,10))
plt.title("Train-Validation Accuracy")
plt.plot(train_acc, label='train')
plt.plot(val_acc, label='validation')
plt.xlabel('num_epochs', fontsize=12)
plt.ylabel('accuracy', fontsize=12)
plt.legend(loc='best')
